# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset to a pandas Dataframe
df=pd.read_csv('C:\\Users\\hp\\Desktop\\New folder\\creditcard.csv')

# %%
# First 5 rows of the dataset
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Last 5 rows of the dataset
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.sample(10)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33266    37160.0  0.808663 -0.516653 -0.474744  1.064405  0.305044  0.488771
# 66339    52001.0  1.381355 -1.190048  0.797680 -1.537248 -1.391083  0.464037
# 208708  137237.0 -2.784612  0.090742  0.586385 -1.572109 -0.894348  0.484350
# 95941    65535.0 -0.931064  0.228542  2.798079  0.261073  0.033874  2.019188
# 82489    59421.0 -2.207371 -1.999159  1.443522  2.237723 -3.239625  1.906969
# 29883    35677.0 -0.765922  0.698478  2.371657  0.038399  0.366671 -0.764980
# 95187    65199.0  1.039009  0.377917  0.716091  2.277331  0.125656  0.714782
# 260559  159616.0 -0.193482  1.045327  0.140502 -0.343942  0.982330 -0.682273
# 39015    39655.0 -1.204922  0.476431  1.939960 -0.372498  0.096073  0.281274
# 148435   89878.0 -2.920882  2.331356 -1.131361 -1.108855  1.333154  1.196648
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
# Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
# Checking the number of missingvalues in each column
df_missing_values = df.isnull().sum()
df_missing_values
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
# Distribution of legit transactions & fraudulent transactions or data distribution analysis
classes = df['Class'].value_counts()
classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(x='Class',data=df)
plt.title('Number of legit vs fraud transactions')
plt.show()

# %%
# separating the data for analysis or Distribution of classes with time
# Creating non fraud dataframe
legit = df[df.Class == 0]
# Creating fraud dataframe
fraud = df[df.Class == 1]

# %%
# Distribution plot
plt.figure(figsize=(8,5))
ax = sns.distplot(fraud['Time'],label='Fraud',hist=False)
ax = sns.distplot(legit['Time'],label='Legit',hist=False)
ax.set(xlabel='Seconds elapsed between the transaction and the first transaction')
plt.show()

# %%
# Droping the Time Column
df.drop('Time', axis=1, inplace=True)

# %%
# Distribution pf classes with amount 
# Distribution plot
plt.figure(figsize=(8,5))
ax = sns.distplot(fraud['Amount'],label='Fraudulent',hist=False)
ax = sns.distplot(legit['Time'],label='Legit',hist=False)
ax.set(xlabel='Transaction Amount')
plt.show()

# %%
legit.shape,fraud.shape
# Out:
# ((284315, 31), (492, 31))

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
df.groupby('Class').mean()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# Class
# 0      0.008258 -0.006271  0.012171 -0.007860  0.005453  0.002419  0.009637
# 1     -4.771948  3.623778 -7.033281  4.542029 -3.151225 -1.397737 -5.568731
#
#              V8        V9       V10  ...       V20       V21       V22  \
# Class                                ...
# 0     -0.000987  0.004467  0.009824  ... -0.000644 -0.001235 -0.000024
# 1      0.570636 -2.581123 -5.676883  ...  0.372319  0.713588  0.014049
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0      0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131   88.291022
# 1     -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667  122.211321
#
# [2 rows x 29 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
df1 = pd.concat([legit_sample, fraud], axis=0)
df1.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 245666  152851.0 -0.313994 -0.084292  1.124108 -1.921419  0.249831 -0.192242
# 211974  138656.0  1.570869 -1.750654  0.429353 -0.255458 -1.680073  0.839919
# 145717   87152.0  2.225231 -1.426693 -0.680584 -1.663111 -1.241569 -0.172904
# 251896  155550.0 -0.846207  1.124905 -1.584026 -0.403769  0.035725 -0.878451
# 205810  135924.0  1.876150 -1.958740 -1.143926 -1.306856 -1.468707 -0.886717
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 245666  0.699388 -0.195747 -0.839699  ... -0.846876 -1.977058  0.262700
# 211974 -1.432371  0.383604  2.684590  ...  0.220013  0.879339 -0.042385
# 145717 -1.329495 -0.032012 -1.436793  ... -0.080193  0.249422  0.269563
# 251896  0.364507 -1.527311  0.574404  ...  1.525598 -0.221639  0.494034
# 205810 -0.662705 -0.378667 -1.356320  ... -0.028068 -0.004030  0.028102
#
# ...

# %%
df1.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
df1['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
df1.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94021.914634  0.038959 -0.009092 -0.003747  0.042976 -0.026068
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.089508  0.067562 -0.061264 -0.084279  ... -0.038042  0.015800
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.012235  0.003672  0.043137  0.029695  0.011792 -0.018410 -0.009782
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       97.089085
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Spliting the data into features & target
x = df1.drop(columns='Class', axis=1)
y = df1['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 245666  152851.0 -0.313994 -0.084292  1.124108 -1.921419  0.249831 -0.192242
# 211974  138656.0  1.570869 -1.750654  0.429353 -0.255458 -1.680073  0.839919
# 145717   87152.0  2.225231 -1.426693 -0.680584 -1.663111 -1.241569 -0.172904
# 251896  155550.0 -0.846207  1.124905 -1.584026 -0.403769  0.035725 -0.878451
# 205810  135924.0  1.876150 -1.958740 -1.143926 -1.306856 -1.468707 -0.886717
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(y)
# Out:
# 245666    0
# 211974    0
# 145717    0
# 251896    0
# 205810    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
# Split the data into Training data & Testing data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2, random_state=100)
x_train.shape, x_test.shape, y_train.shape ,y_test.shape
# Out:
# ((787, 30), (197, 30), (787,), (197,))

# %%
# Feature Scaling
# Standarization method
from sklearn.preprocessing import StandardScaler
# Instantiate the Scaler
scaler = StandardScaler()
# fit the data into scaler and transform
x_train['Amount'] = scaler.fit_transform(x_train[['Amount']])

# %%
x_train.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 120862  75987.0  0.531678 -1.108844  0.276972  0.386453 -1.038906 -0.810526
# 6336     7543.0  0.329594  3.712889 -5.775935  6.078266  1.667359 -2.420168
# 47802   43369.0 -3.365319  2.426503 -3.752227  0.276017 -2.305870 -1.961578
# 123747  77047.0 -1.476316  1.582827  1.065971  1.035165 -0.131731  0.276128
# 49794   44215.0  1.334965 -1.367009  0.387467 -1.362724 -1.621464 -0.611393
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 120862  0.395582 -0.322635  0.068460  ...  0.801043  0.000589 -0.824566
# 6336   -0.812891  0.133080 -2.214311  ...  0.269773  0.156617 -0.652450
# 47802  -3.029283 -1.674462  0.183961  ... -0.036837  2.070008 -0.512626
# 123747  0.635463  0.230630  0.164859  ...  0.566409 -0.127794  0.359617
# 49794  -0.980157 -0.146145 -1.646846  ... -0.125112 -0.343595 -0.894937
#
# ...

# %%
# Transform the test set
x_test['Amount'] = scaler.fit_transform(x_test[['Amount']])
x_test.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223572  143434.0 -2.729482  3.312495 -4.242710  5.036985 -0.376561 -1.532462
# 88307    62080.0 -1.599457  2.607720 -2.987193  3.064156 -2.497914 -0.541103
# 22761    32422.0 -0.779633  0.027990  3.027259 -1.976663 -0.624364 -0.121508
# 249607  154493.0 -7.381547 -7.449015 -4.696287  3.728439  6.198304 -6.406267
# 229712  146022.0  0.908637  2.849024 -5.647343  6.009415  0.216656 -2.397014
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 223572 -3.449159  1.856839 -3.623334  ...  0.164288  0.727415 -0.301432
# 88307  -2.277786  1.268166 -1.997331  ...  0.225333  0.662933  0.184087
# 22761   0.085340 -0.648089 -0.116995  ...  0.264732  0.372066  1.272319
# 249607 -5.831452  1.457175 -0.646203  ...  2.932758  1.176575 -0.978692
# 229712 -1.819308  0.338527 -2.819883  ...  0.241921  0.407260 -0.397435
#
# ...

# %%
# Importing metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, f1_score

# %%
results = pd.DataFrame(columns=['Model Name', 'Accuracy', 'F1-Score', 'ROC'])

# %%
# ROC Curve Function
def draw_roc(actual, probs):
    fpr, tpr, thresholds = metrics.roc_curve(actual, probs, drop_intermediate = False)
    auc_score = metrics.roc_auc_score(actual, probs)
    plt.figure(figsize=(5,5))
    plt.plot(fpr, tpr, label = 'ROC Curve (area = %0.2f)' % auc_score)
    plt.plot([0,1],[0,1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characterictics example')
    plt.legend(loc='lower right')
    plt.show()
    
    return None

# %%
# Importing scikit Logistic regression module
from sklearn.linear_model import LogisticRegression
# Instantiate the model with best C
lr= LogisticRegression(C= 0.01)
logistic_model = lr.fit(x_train, y_train)

# %%
# Prepare results Function
def display_test_results(model_name, model):
    
    # Prediction on the test set 
    y_test_pred = model.predict(x_test)
    
    # Confusion matrix
    print('--------------------------------- Confusion Matrix -----------------------------------')
    c_matrix = metrics.confusion_matrix(y_test, y_test_pred)
    print(c_matrix)
    
    cm_display = ConfusionMatrixDisplay(confusion_matrix = c_matrix)
    cm_display.plot(cmap = plt.cm.Blues)
    plt.show()
    
    # Classification report
    print('--------------------------------- Classification report -----------------------------------')
    print(classification_report(y_test, y_test_pred))
    
    print('--------------------------------- More Specific Classification report -----------------------------------')
    TP = c_matrix[1,1] # true positive
    TN = c_matrix[0,0] # true negative
    FP = c_matrix[0,1] # false positive
    FN = c_matrix[1,0] # false negative
    
    # Accuracy
    print("Accuracy:- ", metrics.accuracy_score(y_test,y_test_pred))
    
    # Sensitivity 
    print("Sensitivity:- ", TP/float(TP+FN))
    
    # Specificity
    print("Specificity:- ", TN/float(TN+FP))
    
    # F1 score
    print("F1-Score:- ",f1_score(y_test,y_test_pred))
    
    # Predicted probability
    y_test_pred_proba = model.predict_proba(x_test)[:,1]
    
    # roc_auc
    print('--------------------------------- ROC -----------------------------------')
    roc_auc = metrics.roc_auc_score(y_test,y_test_pred_proba)
        
    # Plot the ROC Curve
    draw_roc(y_test,y_test_pred_proba)

    # Add all metrics score in final result store
    results.loc[len(results)] = [model_name, metrics.accuracy_score(y_test,y_test_pred), f1_score(y_test,y_test_pred),roc_auc]
    
    return None

# %%
display_test_results("Logistic Regression", logistic_model)
# Out:
# --------------------------------- Confusion Matrix -----------------------------------
# [[104   2]
#  [ 15  76]]
# --------------------------------- Classification report -----------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       106
#            1       0.97      0.84      0.90        91
#
#     accuracy                           0.91       197
#    macro avg       0.92      0.91      0.91       197
# weighted avg       0.92      0.91      0.91       197
#
# --------------------------------- More Specific Classification report -----------------------------------
# Accuracy:-  0.9137055837563451
# Sensitivity:-  0.8351648351648352
# Specificity:-  0.9811320754716981
# F1-Score:-  0.8994082840236687
# --------------------------------- ROC -----------------------------------

# %%
# Importing decision tree classifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Model with optimal hyperparameters
decision_tree_model = DecisionTreeClassifier(criterion = 'gini',
                                            random_state = 100,
                                            max_depth = 5,
                                            min_samples_leaf=100,
                                            min_samples_split=100)
decision_tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=100,
#                        random_state=100)

# %%
display_test_results("Decision Tree", decision_tree_model)
# Out:
# --------------------------------- Confusion Matrix -----------------------------------
# [[106   0]
#  [ 17  74]]
# --------------------------------- Classification report -----------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       106
#            1       1.00      0.81      0.90        91
#
#     accuracy                           0.91       197
#    macro avg       0.93      0.91      0.91       197
# weighted avg       0.93      0.91      0.91       197
#
# --------------------------------- More Specific Classification report -----------------------------------
# Accuracy:-  0.9137055837563451
# Sensitivity:-  0.8131868131868132
# Specificity:-  1.0
# F1-Score:-  0.896969696969697
# --------------------------------- ROC -----------------------------------

# %%
# Importing random forest classifier
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest_model = RandomForestClassifier(bootstrap = True,
                                            max_depth = 5,
                                            min_samples_leaf=50,
                                            min_samples_split=50,
                                            max_features=10,
                                            n_estimators=100)
random_forest_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=10, min_samples_leaf=50,
#                        min_samples_split=50)

# %%
display_test_results("Random Forest", random_forest_model)
# Out:
# --------------------------------- Confusion Matrix -----------------------------------
# [[106   0]
#  [ 11  80]]
# --------------------------------- Classification report -----------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       106
#            1       1.00      0.88      0.94        91
#
#     accuracy                           0.94       197
#    macro avg       0.95      0.94      0.94       197
# weighted avg       0.95      0.94      0.94       197
#
# --------------------------------- More Specific Classification report -----------------------------------
# Accuracy:-  0.9441624365482234
# Sensitivity:-  0.8791208791208791
# Specificity:-  1.0
# F1-Score:-  0.935672514619883
# --------------------------------- ROC -----------------------------------

# %%
# Summary
results.sort_values(by='ROC', ascending=True)
# Out:
#             Model Name  Accuracy  F1-Score       ROC
# 0  Logistic Regression  0.913706  0.899408  0.950860
# 1        Decision Tree  0.913706  0.896970  0.953660
# 2        Random Forest  0.944162  0.935673  0.961124
